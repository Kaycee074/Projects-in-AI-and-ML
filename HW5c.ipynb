# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
################################################################################
# Part 0: Setup & Imports
################################################################################
# !pip install datasets sacrebleu torchtext --quiet

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import random
from datasets import load_dataset
from sacrebleu import corpus_bleu

################################################################################
# Part 1: Implement Scaled Dot-Product Attention
################################################################################
def scaled_dot_product_attention(query, key, value, mask=None):
    """
    query: (batch_size, seq_len_q, d_k)
    key:   (batch_size, seq_len_k, d_k)
    value: (batch_size, seq_len_k, d_v)
    mask:  (batch_size, seq_len_q, seq_len_k) [optional]

    Returns:
        attention_output: (batch_size, seq_len_q, d_v)
        attention_weights: (batch_size, seq_len_q, seq_len_k)
    """
    d_k = query.size(-1)  # dimension of key
    # (batch_size, seq_len_q, seq_len_k)
    scores = torch.bmm(query, key.transpose(1, 2)) / (d_k ** 0.5)

    if mask is not None:
        scores = scores.masked_fill(mask == 0, float('-inf'))

    # (batch_size, seq_len_q, seq_len_k)
    attn_weights = F.softmax(scores, dim=-1)
    # (batch_size, seq_len_q, d_v)
    output = torch.bmm(attn_weights, value)
    return output, attn_weights

################################################################################
# Part 2: Seq2Seq Model with Encoder, Decoder & Attention
################################################################################

# ------------------- 2.1 Simple Tokenizer -------------------
def tokenize(text):
    # Very naive splitting on whitespace
    return text.lower().strip().split()

# ------------------- 2.2 Vocabulary Building -------------------
# We'll build minimal vocab from a small subset for demonstration
def build_vocab(lines, max_tokens=5000):
    freq = {}
    for line in lines:
        for token in tokenize(line):
            freq[token] = freq.get(token, 0) + 1
    # Sort by frequency
    sorted_freq = sorted(freq.items(), key=lambda x: x[1], reverse=True)
    # Special tokens
    vocab = ["<pad>", "<bos>", "<eos>", "<unk>"]
    for word, _ in sorted_freq[: max_tokens - len(vocab)]:
        vocab.append(word)
    word2idx = {w: i for i, w in enumerate(vocab)}
    idx2word = {i: w for w, i in word2idx.items()}
    return vocab, word2idx, idx2word

def numericalize(line, word2idx):
    tokens = ["<bos>"] + tokenize(line) + ["<eos>"]
    return [word2idx.get(t, word2idx["<unk>"]) for t in tokens]

# ------------------- 2.3 Encoder -------------------
class Encoder(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim):
        super().__init__()
        self.embed = nn.Embedding(vocab_size, embed_dim, padding_idx=0)
        self.rnn = nn.GRU(embed_dim, hidden_dim, batch_first=True)

    def forward(self, src):
        # src: (batch_size, seq_len)
        embedded = self.embed(src)  # (batch_size, seq_len, embed_dim)
        outputs, hidden = self.rnn(embedded)
        # outputs: (batch_size, seq_len, hidden_dim)
        # hidden: (1, batch_size, hidden_dim)
        return outputs, hidden

# ------------------- 2.4 Decoder with Scaled Dot-Product Attention -------------------
class Decoder(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim):
        super().__init__()
        self.embed = nn.Embedding(vocab_size, embed_dim, padding_idx=0)
        self.rnn = nn.GRU(embed_dim, hidden_dim, batch_first=True)
        self.fc_out = nn.Linear(hidden_dim, vocab_size)
        self.hidden_dim = hidden_dim

    def forward(self, tgt, hidden, encoder_outputs):
        # tgt: (batch_size, tgt_seq_len)
        # hidden: (1, batch_size, hidden_dim)
        # encoder_outputs: (batch_size, src_seq_len, hidden_dim)
        embedded = self.embed(tgt)  # (batch_size, tgt_seq_len, embed_dim)
        rnn_out, hidden = self.rnn(embedded, hidden)  # rnn_out: (batch_size, tgt_seq_len, hidden_dim)

        # For simplicity, we apply scaled dot-product attention
        # with query=rnn_out, key=encoder_outputs, value=encoder_outputs
        # shapes:
        #  query: (batch_size, tgt_seq_len, hidden_dim)
        #  key:   (batch_size, src_seq_len, hidden_dim)
        #  value: (batch_size, src_seq_len, hidden_dim)
        context, attn_weights = scaled_dot_product_attention(rnn_out, encoder_outputs, encoder_outputs)

        # Combine context with rnn_out
        combined = rnn_out + context  # (batch_size, tgt_seq_len, hidden_dim)

        logits = self.fc_out(combined)  # (batch_size, tgt_seq_len, vocab_size)
        return logits, hidden, attn_weights

# ------------------- 2.5 Full Seq2Seq -------------------
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder):
        super().__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, src, tgt):
        # Encode
        enc_outputs, enc_hidden = self.encoder(src)
        # Decode
        logits, dec_hidden, attn_weights = self.decoder(tgt, enc_hidden, enc_outputs)
        return logits

################################################################################
# Part 3: Machine Translation with a Subset of IWSLT2017 + Evaluate BLEU
################################################################################
def pad_batch(batch, pad_idx=0):
    """Pad a list of token lists to the same length."""
    max_len = max(len(seq) for seq in batch)
    padded = []
    for seq in batch:
        seq = seq + [pad_idx] * (max_len - len(seq))
        padded.append(seq)
    return torch.tensor(padded, dtype=torch.long)

# Minimal training loop
def train_epoch(model, dataloader, optimizer, criterion, device):
    model.train()
    total_loss = 0
    for src_batch, tgt_batch in dataloader:
        src_batch = src_batch.to(device)
        tgt_batch = tgt_batch.to(device)

        # teacher forcing:
        # let input to decoder be everything except last token
        dec_in = tgt_batch[:, :-1]
        # we want to predict everything except first token
        dec_target = tgt_batch[:, 1:].contiguous().view(-1)

        optimizer.zero_grad()
        logits = model(src_batch, dec_in)  # (batch_size, seq_len, vocab_size)
        logits = logits.view(-1, logits.size(-1))  # flatten
        loss = criterion(logits, dec_target)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
    return total_loss / len(dataloader)

def evaluate_bleu(model, src_list, tgt_list, src_word2idx, tgt_word2idx, tgt_idx2word, device, max_len=50):
    """Simple greedy decode + BLEU calculation using sacrebleu."""
    model.eval()
    preds = []
    refs = []
    with torch.no_grad():
        for i in range(len(src_list)):
            # Convert to tensor
            src_tensor = torch.tensor(src_list[i], dtype=torch.long).unsqueeze(0).to(device)
            enc_outputs, enc_hidden = model.encoder(src_tensor)

            # Greedy decode
            dec_input = torch.tensor([tgt_word2idx["<bos>"]], dtype=torch.long).unsqueeze(0).to(device)
            hidden = enc_hidden
            pred_tokens = []
            for _ in range(max_len):
                logits, hidden, attn_weights = model.decoder(dec_input, hidden, enc_outputs)
                next_token = logits[:, -1, :].argmax(dim=-1)
                token_id = next_token.item()
                if token_id == tgt_word2idx["<eos>"]:
                    break
                pred_tokens.append(token_id)
                dec_input = torch.cat([dec_input, next_token.unsqueeze(0)], dim=1)

            # Convert IDs to text
            pred_words = [tgt_idx2word.get(idx, "<unk>") for idx in pred_tokens]
            preds.append(" ".join(pred_words))

            # Prepare reference
            ref_line = [t for t in tokenize(tgt_list[i]) if t != ""]
            refs.append([" ".join(ref_line)])  # sacrebleu expects a list of references
    # Calculate BLEU
    bleu = corpus_bleu(preds, refs)
    return bleu.score

def main():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print("Using device:", device)

    ############################################################################
    # 1. Load IWSLT 2017 De-En
    ############################################################################
    dataset = load_dataset("iwslt2017", "iwslt2017-de-en")
    train_data = dataset["train"]
    valid_data = dataset["validation"]
    test_data = dataset["test"]

    # 2. Subset the dataset (e.g., 2000 train, 200 valid, 200 test)
    #    for demonstration
    train_subset = train_data.select(range(2000))
    valid_subset = valid_data.select(range(200))
    test_subset  = test_data.select(range(200))

    # Extract raw text
    train_src = [ex["translation"]["de"] for ex in train_subset]
    train_tgt = [ex["translation"]["en"] for ex in train_subset]

    valid_src = [ex["translation"]["de"] for ex in valid_subset]
    valid_tgt = [ex["translation"]["en"] for ex in valid_subset]

    test_src = [ex["translation"]["de"] for ex in test_subset]
    test_tgt = [ex["translation"]["en"] for ex in test_subset]

    ############################################################################
    # 3. Build Vocabulary (tiny for demonstration)
    ############################################################################
    src_vocab, src_w2i, src_i2w = build_vocab(train_src, max_tokens=3000)
    tgt_vocab, tgt_w2i, tgt_i2w = build_vocab(train_tgt, max_tokens=3000)

    print(f"Source vocab size: {len(src_vocab)}, Target vocab size: {len(tgt_vocab)}")

    # 4. Numericalize
    train_src_num = [numericalize(line, src_w2i) for line in train_src]
    train_tgt_num = [numericalize(line, tgt_w2i) for line in train_tgt]

    valid_src_num = [numericalize(line, src_w2i) for line in valid_src]
    valid_tgt_num = [numericalize(line, tgt_w2i) for line in valid_tgt]

    test_src_num  = [numericalize(line, src_w2i) for line in test_src]
    test_tgt_num  = [numericalize(line, tgt_w2i) for line in test_tgt]

    ############################################################################
    # 5. Create Dataloaders
    ############################################################################
    BATCH_SIZE = 32

    def collate_fn(batch):
        # batch: list of tuples (src_seq, tgt_seq)
        src_seqs, tgt_seqs = zip(*batch)
        src_pad = pad_batch(src_seqs, pad_idx=0)
        tgt_pad = pad_batch(tgt_seqs, pad_idx=0)
        return src_pad, tgt_pad

    train_pairs = list(zip(train_src_num, train_tgt_num))
    valid_pairs = list(zip(valid_src_num, valid_tgt_num))

    train_loader = torch.utils.data.DataLoader(
        train_pairs, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_fn
    )
    valid_loader = torch.utils.data.DataLoader(
        valid_pairs, batch_size=BATCH_SIZE, shuffle=False, collate_fn=collate_fn
    )

    ############################################################################
    # 6. Initialize Model, Optimizer, Loss
    ############################################################################
    SRC_VOCAB_SIZE = len(src_vocab)
    TGT_VOCAB_SIZE = len(tgt_vocab)
    EMBED_DIM = 128
    HIDDEN_DIM = 256

    encoder = Encoder(SRC_VOCAB_SIZE, EMBED_DIM, HIDDEN_DIM)
    decoder = Decoder(TGT_VOCAB_SIZE, EMBED_DIM, HIDDEN_DIM)
    model = Seq2Seq(encoder, decoder).to(device)

    optimizer = optim.Adam(model.parameters(), lr=1e-3)
    criterion = nn.CrossEntropyLoss(ignore_index=0)  # ignore <pad>

    ############################################################################
    # 7. Training Loop
    ############################################################################
    EPOCHS = 500
    for epoch in range(1, EPOCHS + 1):
        train_loss = train_epoch(model, train_loader, optimizer, criterion, device)
        print(f"Epoch [{epoch}/{EPOCHS}] - Train Loss: {train_loss:.4f}")

    ############################################################################
    # 8. Evaluate on a small valid subset (Optional)
    ############################################################################
    # We won't do a thorough validation loop here for brevity,
    # but you could decode and compute BLEU on valid pairs similarly to test.

    ############################################################################
    # 9. Test BLEU
    ############################################################################
    bleu_score = evaluate_bleu(
        model, test_src_num, test_tgt, src_w2i, tgt_w2i, tgt_i2w, device
    )
    print(f"\nTest BLEU Score: {bleu_score:.2f}")

if __name__ == "__main__":
    main()
# Out:
# Using device: cuda
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Source vocab size: 3000, Target vocab size: 3000
# Epoch [1/500] - Train Loss: 6.0901
# Epoch [2/500] - Train Loss: 5.2638
# Epoch [3/500] - Train Loss: 4.8908
# Epoch [4/500] - Train Loss: 4.5682
# Epoch [5/500] - Train Loss: 4.2611
# Epoch [6/500] - Train Loss: 3.9774
# Epoch [7/500] - Train Loss: 3.7032
# Epoch [8/500] - Train Loss: 3.4368
# Epoch [9/500] - Train Loss: 3.1687
# Epoch [10/500] - Train Loss: 2.9063
# Epoch [11/500] - Train Loss: 2.6494
# Epoch [12/500] - Train Loss: 2.4052
# Epoch [13/500] - Train Loss: 2.1720
# Epoch [14/500] - Train Loss: 1.9537
# Epoch [15/500] - Train Loss: 1.7422
# Epoch [16/500] - Train Loss: 1.5488
# Epoch [17/500] - Train Loss: 1.3690
# Epoch [18/500] - Train Loss: 1.2042
# Epoch [19/500] - Train Loss: 1.0496
# Epoch [20/500] - Train Loss: 0.9182
# Epoch [21/500] - Train Loss: 0.7890
# Epoch [22/500] - Train Loss: 0.6800
# Epoch [23/500] - Train Loss: 0.5902
# Epoch [24/500] - Train Loss: 0.5001
# Epoch [25/500] - Train Loss: 0.4244
# Epoch [26/500] - Train Loss: 0.3599
# Epoch [27/500] - Train Loss: 0.3091
# Epoch [28/500] - Train Loss: 0.2629
# Epoch [29/500] - Train Loss: 0.2233
# Epoch [30/500] - Train Loss: 0.1928
# Epoch [31/500] - Train Loss: 0.1656
# Epoch [32/500] - Train Loss: 0.1429
# Epoch [33/500] - Train Loss: 0.1236
# Epoch [34/500] - Train Loss: 0.1088
# Epoch [35/500] - Train Loss: 0.0958
# Epoch [36/500] - Train Loss: 0.0851
# Epoch [37/500] - Train Loss: 0.0760
# Epoch [38/500] - Train Loss: 0.0692
# Epoch [39/500] - Train Loss: 0.0625
# Epoch [40/500] - Train Loss: 0.0565
# Epoch [41/500] - Train Loss: 0.0536
# Epoch [42/500] - Train Loss: 0.0492
# Epoch [43/500] - Train Loss: 0.0439
# Epoch [44/500] - Train Loss: 0.0405
# Epoch [45/500] - Train Loss: 0.0374
# Epoch [46/500] - Train Loss: 0.0345
# Epoch [47/500] - Train Loss: 0.0323
# Epoch [48/500] - Train Loss: 0.0302
# Epoch [49/500] - Train Loss: 0.0285
# Epoch [50/500] - Train Loss: 0.0261
# Epoch [51/500] - Train Loss: 0.0258
# Epoch [52/500] - Train Loss: 0.0252
# Epoch [53/500] - Train Loss: 0.0229
# Epoch [54/500] - Train Loss: 0.0217
# Epoch [55/500] - Train Loss: 0.0199
# Epoch [56/500] - Train Loss: 0.0185
# Epoch [57/500] - Train Loss: 0.0175
# Epoch [58/500] - Train Loss: 0.0171
# Epoch [59/500] - Train Loss: 0.0167
# Epoch [60/500] - Train Loss: 0.0164
# Epoch [61/500] - Train Loss: 0.0173
# Epoch [62/500] - Train Loss: 0.0206
# Epoch [63/500] - Train Loss: 0.0238
# Epoch [64/500] - Train Loss: 0.0333
# Epoch [65/500] - Train Loss: 0.0599
# Epoch [66/500] - Train Loss: 0.0900
# Epoch [67/500] - Train Loss: 0.1101
# Epoch [68/500] - Train Loss: 0.0710
# Epoch [69/500] - Train Loss: 0.0332
# Epoch [70/500] - Train Loss: 0.0186
# Epoch [71/500] - Train Loss: 0.0136
# Epoch [72/500] - Train Loss: 0.0119
# Epoch [73/500] - Train Loss: 0.0108
# Epoch [74/500] - Train Loss: 0.0099
# Epoch [75/500] - Train Loss: 0.0093
# Epoch [76/500] - Train Loss: 0.0082
# Epoch [77/500] - Train Loss: 0.0078
# Epoch [78/500] - Train Loss: 0.0075
# Epoch [79/500] - Train Loss: 0.0072
# Epoch [80/500] - Train Loss: 0.0066
# Epoch [81/500] - Train Loss: 0.0063
# Epoch [82/500] - Train Loss: 0.0060
# Epoch [83/500] - Train Loss: 0.0059
# Epoch [84/500] - Train Loss: 0.0057
# Epoch [85/500] - Train Loss: 0.0054
# Epoch [86/500] - Train Loss: 0.0052
# Epoch [87/500] - Train Loss: 0.0048
# Epoch [88/500] - Train Loss: 0.0048
# Epoch [89/500] - Train Loss: 0.0047
# Epoch [90/500] - Train Loss: 0.0044
# Epoch [91/500] - Train Loss: 0.0044
# Epoch [92/500] - Train Loss: 0.0044
# Epoch [93/500] - Train Loss: 0.0052
# Epoch [94/500] - Train Loss: 0.0048
# Epoch [95/500] - Train Loss: 0.0040
# Epoch [96/500] - Train Loss: 0.0040
# Epoch [97/500] - Train Loss: 0.0046
# Epoch [98/500] - Train Loss: 0.0042
# Epoch [99/500] - Train Loss: 0.0038
# Epoch [100/500] - Train Loss: 0.0033
# Epoch [101/500] - Train Loss: 0.0033
# Epoch [102/500] - Train Loss: 0.0038
# Epoch [103/500] - Train Loss: 0.0048
# Epoch [104/500] - Train Loss: 0.0066
# Epoch [105/500] - Train Loss: 0.0744
# Epoch [106/500] - Train Loss: 0.2802
# Epoch [107/500] - Train Loss: 0.1807
# Epoch [108/500] - Train Loss: 0.0605
# Epoch [109/500] - Train Loss: 0.0227
# Epoch [110/500] - Train Loss: 0.0120
# Epoch [111/500] - Train Loss: 0.0088
# Epoch [112/500] - Train Loss: 0.0078
# Epoch [113/500] - Train Loss: 0.0069
# Epoch [114/500] - Train Loss: 0.0062
# Epoch [115/500] - Train Loss: 0.0058
# Epoch [116/500] - Train Loss: 0.0054
# Epoch [117/500] - Train Loss: 0.0053
# Epoch [118/500] - Train Loss: 0.0048
# Epoch [119/500] - Train Loss: 0.0044
# Epoch [120/500] - Train Loss: 0.0043
# Epoch [121/500] - Train Loss: 0.0041
# Epoch [122/500] - Train Loss: 0.0037
# Epoch [123/500] - Train Loss: 0.0035
# Epoch [124/500] - Train Loss: 0.0035
# Epoch [125/500] - Train Loss: 0.0033
# Epoch [126/500] - Train Loss: 0.0032
# Epoch [127/500] - Train Loss: 0.0030
# Epoch [128/500] - Train Loss: 0.0028
# Epoch [129/500] - Train Loss: 0.0027
# Epoch [130/500] - Train Loss: 0.0027
# Epoch [131/500] - Train Loss: 0.0027
# Epoch [132/500] - Train Loss: 0.0024
# Epoch [133/500] - Train Loss: 0.0023
# Epoch [134/500] - Train Loss: 0.0024
# Epoch [135/500] - Train Loss: 0.0023
# Epoch [136/500] - Train Loss: 0.0022
# Epoch [137/500] - Train Loss: 0.0022
# Epoch [138/500] - Train Loss: 0.0020
# Epoch [139/500] - Train Loss: 0.0019
# Epoch [140/500] - Train Loss: 0.0019
# Epoch [141/500] - Train Loss: 0.0018
# Epoch [142/500] - Train Loss: 0.0019
# Epoch [143/500] - Train Loss: 0.0024
# Epoch [144/500] - Train Loss: 0.0029
# Epoch [145/500] - Train Loss: 0.0023
# Epoch [146/500] - Train Loss: 0.0026
# Epoch [147/500] - Train Loss: 0.0035
# Epoch [148/500] - Train Loss: 0.0035
# Epoch [149/500] - Train Loss: 0.0034
# Epoch [150/500] - Train Loss: 0.0027
# Epoch [151/500] - Train Loss: 0.0028
# Epoch [152/500] - Train Loss: 0.0025
# Epoch [153/500] - Train Loss: 0.0030
# Epoch [154/500] - Train Loss: 0.0024
# Epoch [155/500] - Train Loss: 0.0021
# Epoch [156/500] - Train Loss: 0.0017
# Epoch [157/500] - Train Loss: 0.0015
# Epoch [158/500] - Train Loss: 0.0014
# Epoch [159/500] - Train Loss: 0.0014
# Epoch [160/500] - Train Loss: 0.0013
# Epoch [161/500] - Train Loss: 0.0012
# Epoch [162/500] - Train Loss: 0.0012
# Epoch [163/500] - Train Loss: 0.0014
# Epoch [164/500] - Train Loss: 0.0014
# Epoch [165/500] - Train Loss: 0.0014
# Epoch [166/500] - Train Loss: 0.0023
# Epoch [167/500] - Train Loss: 0.0036
# Epoch [168/500] - Train Loss: 0.0054
# Epoch [169/500] - Train Loss: 0.0483
# Epoch [170/500] - Train Loss: 0.2781
# Epoch [171/500] - Train Loss: 0.2011
# Epoch [172/500] - Train Loss: 0.0717
# Epoch [173/500] - Train Loss: 0.0221
# Epoch [174/500] - Train Loss: 0.0086
# Epoch [175/500] - Train Loss: 0.0060
# Epoch [176/500] - Train Loss: 0.0049
# Epoch [177/500] - Train Loss: 0.0044
# Epoch [178/500] - Train Loss: 0.0038
# Epoch [179/500] - Train Loss: 0.0035
# Epoch [180/500] - Train Loss: 0.0033
# Epoch [181/500] - Train Loss: 0.0030
# Epoch [182/500] - Train Loss: 0.0028
# Epoch [183/500] - Train Loss: 0.0026
# Epoch [184/500] - Train Loss: 0.0025
# Epoch [185/500] - Train Loss: 0.0025
# Epoch [186/500] - Train Loss: 0.0023
# Epoch [187/500] - Train Loss: 0.0023
# Epoch [188/500] - Train Loss: 0.0022
# Epoch [189/500] - Train Loss: 0.0020
# Epoch [190/500] - Train Loss: 0.0020
# Epoch [191/500] - Train Loss: 0.0018
# Epoch [192/500] - Train Loss: 0.0019
# Epoch [193/500] - Train Loss: 0.0019
# Epoch [194/500] - Train Loss: 0.0018
# Epoch [195/500] - Train Loss: 0.0018
# Epoch [196/500] - Train Loss: 0.0016
# Epoch [197/500] - Train Loss: 0.0014
# Epoch [198/500] - Train Loss: 0.0014
# Epoch [199/500] - Train Loss: 0.0014
# Epoch [200/500] - Train Loss: 0.0015
# Epoch [201/500] - Train Loss: 0.0013
# Epoch [202/500] - Train Loss: 0.0014
# Epoch [203/500] - Train Loss: 0.0014
# Epoch [204/500] - Train Loss: 0.0012
# Epoch [205/500] - Train Loss: 0.0012
# Epoch [206/500] - Train Loss: 0.0012
# Epoch [207/500] - Train Loss: 0.0012
# Epoch [208/500] - Train Loss: 0.0013
# Epoch [209/500] - Train Loss: 0.0011
# Epoch [210/500] - Train Loss: 0.0011
# Epoch [211/500] - Train Loss: 0.0012
# Epoch [212/500] - Train Loss: 0.0011
# Epoch [213/500] - Train Loss: 0.0010
# Epoch [214/500] - Train Loss: 0.0013
# Epoch [215/500] - Train Loss: 0.0010
# Epoch [216/500] - Train Loss: 0.0010
# Epoch [217/500] - Train Loss: 0.0009
# Epoch [218/500] - Train Loss: 0.0009
# Epoch [219/500] - Train Loss: 0.0010
# Epoch [220/500] - Train Loss: 0.0009
# Epoch [221/500] - Train Loss: 0.0009
# Epoch [222/500] - Train Loss: 0.0010
# Epoch [223/500] - Train Loss: 0.0008
# Epoch [224/500] - Train Loss: 0.0008
# Epoch [225/500] - Train Loss: 0.0008
# Epoch [226/500] - Train Loss: 0.0007
# Epoch [227/500] - Train Loss: 0.0007
# Epoch [228/500] - Train Loss: 0.0008
# Epoch [229/500] - Train Loss: 0.0007
# Epoch [230/500] - Train Loss: 0.0007
# Epoch [231/500] - Train Loss: 0.0008
# Epoch [232/500] - Train Loss: 0.0009
# Epoch [233/500] - Train Loss: 0.0008
# Epoch [234/500] - Train Loss: 0.0033
# Epoch [235/500] - Train Loss: 0.0510
# Epoch [236/500] - Train Loss: 0.2816
# Epoch [237/500] - Train Loss: 0.1948
# Epoch [238/500] - Train Loss: 0.0753
# Epoch [239/500] - Train Loss: 0.0255
# Epoch [240/500] - Train Loss: 0.0100
# Epoch [241/500] - Train Loss: 0.0055
# Epoch [242/500] - Train Loss: 0.0044
# Epoch [243/500] - Train Loss: 0.0038
# Epoch [244/500] - Train Loss: 0.0035
# Epoch [245/500] - Train Loss: 0.0030
# Epoch [246/500] - Train Loss: 0.0029
# Epoch [247/500] - Train Loss: 0.0028
# Epoch [248/500] - Train Loss: 0.0025
# Epoch [249/500] - Train Loss: 0.0023
# Epoch [250/500] - Train Loss: 0.0021
# Epoch [251/500] - Train Loss: 0.0021
# Epoch [252/500] - Train Loss: 0.0020
# Epoch [253/500] - Train Loss: 0.0020
# Epoch [254/500] - Train Loss: 0.0018
# Epoch [255/500] - Train Loss: 0.0018
# Epoch [256/500] - Train Loss: 0.0018
# Epoch [257/500] - Train Loss: 0.0016
# Epoch [258/500] - Train Loss: 0.0016
# Epoch [259/500] - Train Loss: 0.0015
# Epoch [260/500] - Train Loss: 0.0015
# Epoch [261/500] - Train Loss: 0.0014
# Epoch [262/500] - Train Loss: 0.0013
# Epoch [263/500] - Train Loss: 0.0014
# Epoch [264/500] - Train Loss: 0.0013
# Epoch [265/500] - Train Loss: 0.0013
# Epoch [266/500] - Train Loss: 0.0012
# Epoch [267/500] - Train Loss: 0.0012
# Epoch [268/500] - Train Loss: 0.0011
# Epoch [269/500] - Train Loss: 0.0012
# Epoch [270/500] - Train Loss: 0.0012
# Epoch [271/500] - Train Loss: 0.0011
# Epoch [272/500] - Train Loss: 0.0010
# Epoch [273/500] - Train Loss: 0.0010
# Epoch [274/500] - Train Loss: 0.0009
# Epoch [275/500] - Train Loss: 0.0009
# Epoch [276/500] - Train Loss: 0.0010
# Epoch [277/500] - Train Loss: 0.0012
# Epoch [278/500] - Train Loss: 0.0011
# Epoch [279/500] - Train Loss: 0.0009
# Epoch [280/500] - Train Loss: 0.0009
# Epoch [281/500] - Train Loss: 0.0009
# Epoch [282/500] - Train Loss: 0.0009
# Epoch [283/500] - Train Loss: 0.0009
# Epoch [284/500] - Train Loss: 0.0009
# Epoch [285/500] - Train Loss: 0.0024
# Epoch [286/500] - Train Loss: 0.0028
# Epoch [287/500] - Train Loss: 0.0058
# Epoch [288/500] - Train Loss: 0.0115
# Epoch [289/500] - Train Loss: 0.0467
# Epoch [290/500] - Train Loss: 0.1287
# Epoch [291/500] - Train Loss: 0.1220
# Epoch [292/500] - Train Loss: 0.0628
# Epoch [293/500] - Train Loss: 0.0239
# Epoch [294/500] - Train Loss: 0.0093
# Epoch [295/500] - Train Loss: 0.0042
# Epoch [296/500] - Train Loss: 0.0033
# Epoch [297/500] - Train Loss: 0.0028
# Epoch [298/500] - Train Loss: 0.0024
# Epoch [299/500] - Train Loss: 0.0021
# Epoch [300/500] - Train Loss: 0.0019
# Epoch [301/500] - Train Loss: 0.0019
# Epoch [302/500] - Train Loss: 0.0018
# Epoch [303/500] - Train Loss: 0.0017
# Epoch [304/500] - Train Loss: 0.0015
# Epoch [305/500] - Train Loss: 0.0014
# Epoch [306/500] - Train Loss: 0.0014
# Epoch [307/500] - Train Loss: 0.0014
# Epoch [308/500] - Train Loss: 0.0013
# Epoch [309/500] - Train Loss: 0.0012
# Epoch [310/500] - Train Loss: 0.0012
# Epoch [311/500] - Train Loss: 0.0011
# Epoch [312/500] - Train Loss: 0.0011
# Epoch [313/500] - Train Loss: 0.0011
# Epoch [314/500] - Train Loss: 0.0012
# Epoch [315/500] - Train Loss: 0.0010
# Epoch [316/500] - Train Loss: 0.0009
# Epoch [317/500] - Train Loss: 0.0009
# Epoch [318/500] - Train Loss: 0.0009
# Epoch [319/500] - Train Loss: 0.0009
# Epoch [320/500] - Train Loss: 0.0009
# Epoch [321/500] - Train Loss: 0.0009
# Epoch [322/500] - Train Loss: 0.0009
# Epoch [323/500] - Train Loss: 0.0010
# Epoch [324/500] - Train Loss: 0.0008
# Epoch [325/500] - Train Loss: 0.0007
# Epoch [326/500] - Train Loss: 0.0007
# Epoch [327/500] - Train Loss: 0.0008
# Epoch [328/500] - Train Loss: 0.0007
# Epoch [329/500] - Train Loss: 0.0008
# Epoch [330/500] - Train Loss: 0.0006
# Epoch [331/500] - Train Loss: 0.0006
# Epoch [332/500] - Train Loss: 0.0006
# Epoch [333/500] - Train Loss: 0.0006
# Epoch [334/500] - Train Loss: 0.0007
# Epoch [335/500] - Train Loss: 0.0007
# Epoch [336/500] - Train Loss: 0.0007
# Epoch [337/500] - Train Loss: 0.0011
# Epoch [338/500] - Train Loss: 0.0007
# Epoch [339/500] - Train Loss: 0.0020
# Epoch [340/500] - Train Loss: 0.0053
# Epoch [341/500] - Train Loss: 0.0148
# Epoch [342/500] - Train Loss: 0.0805
# Epoch [343/500] - Train Loss: 0.1768
# Epoch [344/500] - Train Loss: 0.1168
# Epoch [345/500] - Train Loss: 0.0482
# Epoch [346/500] - Train Loss: 0.0157
# Epoch [347/500] - Train Loss: 0.0058
# Epoch [348/500] - Train Loss: 0.0036
# Epoch [349/500] - Train Loss: 0.0029
# Epoch [350/500] - Train Loss: 0.0024
# Epoch [351/500] - Train Loss: 0.0022
# Epoch [352/500] - Train Loss: 0.0021
# Epoch [353/500] - Train Loss: 0.0019
# Epoch [354/500] - Train Loss: 0.0017
# Epoch [355/500] - Train Loss: 0.0017
# Epoch [356/500] - Train Loss: 0.0016
# Epoch [357/500] - Train Loss: 0.0015
# Epoch [358/500] - Train Loss: 0.0014
# Epoch [359/500] - Train Loss: 0.0013
# Epoch [360/500] - Train Loss: 0.0012
# Epoch [361/500] - Train Loss: 0.0012
# Epoch [362/500] - Train Loss: 0.0012
# Epoch [363/500] - Train Loss: 0.0011
# Epoch [364/500] - Train Loss: 0.0011
# Epoch [365/500] - Train Loss: 0.0010
# Epoch [366/500] - Train Loss: 0.0010
# Epoch [367/500] - Train Loss: 0.0010
# Epoch [368/500] - Train Loss: 0.0011
# Epoch [369/500] - Train Loss: 0.0011
# Epoch [370/500] - Train Loss: 0.0012
# Epoch [371/500] - Train Loss: 0.0009
# Epoch [372/500] - Train Loss: 0.0008
# Epoch [373/500] - Train Loss: 0.0008
# Epoch [374/500] - Train Loss: 0.0008
# Epoch [375/500] - Train Loss: 0.0009
# Epoch [376/500] - Train Loss: 0.0010
# Epoch [377/500] - Train Loss: 0.0008
# Epoch [378/500] - Train Loss: 0.0009
# Epoch [379/500] - Train Loss: 0.0009
# Epoch [380/500] - Train Loss: 0.0007
# Epoch [381/500] - Train Loss: 0.0007
# Epoch [382/500] - Train Loss: 0.0007
# Epoch [383/500] - Train Loss: 0.0008
# Epoch [384/500] - Train Loss: 0.0007
# Epoch [385/500] - Train Loss: 0.0006
# Epoch [386/500] - Train Loss: 0.0006
# Epoch [387/500] - Train Loss: 0.0006
# Epoch [388/500] - Train Loss: 0.0007
# Epoch [389/500] - Train Loss: 0.0008
# Epoch [390/500] - Train Loss: 0.0008
# Epoch [391/500] - Train Loss: 0.0008
# Epoch [392/500] - Train Loss: 0.0007
# Epoch [393/500] - Train Loss: 0.0006
# Epoch [394/500] - Train Loss: 0.0005
# Epoch [395/500] - Train Loss: 0.0005
# Epoch [396/500] - Train Loss: 0.0007
# Epoch [397/500] - Train Loss: 0.0005
# Epoch [398/500] - Train Loss: 0.0006
# Epoch [399/500] - Train Loss: 0.0010
# Epoch [400/500] - Train Loss: 0.0010
# Epoch [401/500] - Train Loss: 0.0007
# Epoch [402/500] - Train Loss: 0.0006
# Epoch [403/500] - Train Loss: 0.0005
# Epoch [404/500] - Train Loss: 0.0005
# Epoch [405/500] - Train Loss: 0.0010
# Epoch [406/500] - Train Loss: 0.0005
# Epoch [407/500] - Train Loss: 0.0013
# Epoch [408/500] - Train Loss: 0.0011
# Epoch [409/500] - Train Loss: 0.0009
# Epoch [410/500] - Train Loss: 0.0009
# Epoch [411/500] - Train Loss: 0.0009
# Epoch [412/500] - Train Loss: 0.0008
# Epoch [413/500] - Train Loss: 0.0037
# Epoch [414/500] - Train Loss: 0.0889
# Epoch [415/500] - Train Loss: 0.3095
# Epoch [416/500] - Train Loss: 0.1731
# Epoch [417/500] - Train Loss: 0.0603
# Epoch [418/500] - Train Loss: 0.0196
# Epoch [419/500] - Train Loss: 0.0077
# Epoch [420/500] - Train Loss: 0.0045
# Epoch [421/500] - Train Loss: 0.0037
# Epoch [422/500] - Train Loss: 0.0030
# Epoch [423/500] - Train Loss: 0.0030
# Epoch [424/500] - Train Loss: 0.0025
# Epoch [425/500] - Train Loss: 0.0023
# Epoch [426/500] - Train Loss: 0.0021
# Epoch [427/500] - Train Loss: 0.0020
# Epoch [428/500] - Train Loss: 0.0018
# Epoch [429/500] - Train Loss: 0.0018
# Epoch [430/500] - Train Loss: 0.0017
# Epoch [431/500] - Train Loss: 0.0018
# Epoch [432/500] - Train Loss: 0.0016
# Epoch [433/500] - Train Loss: 0.0015
# Epoch [434/500] - Train Loss: 0.0014
# Epoch [435/500] - Train Loss: 0.0014
# Epoch [436/500] - Train Loss: 0.0013
# Epoch [437/500] - Train Loss: 0.0013
# Epoch [438/500] - Train Loss: 0.0012
# Epoch [439/500] - Train Loss: 0.0012
# Epoch [440/500] - Train Loss: 0.0011
# Epoch [441/500] - Train Loss: 0.0011
# Epoch [442/500] - Train Loss: 0.0012
# Epoch [443/500] - Train Loss: 0.0011
# Epoch [444/500] - Train Loss: 0.0014
# Epoch [445/500] - Train Loss: 0.0011
# Epoch [446/500] - Train Loss: 0.0011
# Epoch [447/500] - Train Loss: 0.0009
# Epoch [448/500] - Train Loss: 0.0010
# Epoch [449/500] - Train Loss: 0.0012
# Epoch [450/500] - Train Loss: 0.0010
# Epoch [451/500] - Train Loss: 0.0008
# Epoch [452/500] - Train Loss: 0.0009
# Epoch [453/500] - Train Loss: 0.0008
# Epoch [454/500] - Train Loss: 0.0009
# Epoch [455/500] - Train Loss: 0.0009
# Epoch [456/500] - Train Loss: 0.0008
# Epoch [457/500] - Train Loss: 0.0009
# Epoch [458/500] - Train Loss: 0.0009
# Epoch [459/500] - Train Loss: 0.0007
# Epoch [460/500] - Train Loss: 0.0007
# Epoch [461/500] - Train Loss: 0.0007
# Epoch [462/500] - Train Loss: 0.0007
# Epoch [463/500] - Train Loss: 0.0006
# Epoch [464/500] - Train Loss: 0.0006
# Epoch [465/500] - Train Loss: 0.0007
# Epoch [466/500] - Train Loss: 0.0007
# Epoch [467/500] - Train Loss: 0.0007
# Epoch [468/500] - Train Loss: 0.0007
# Epoch [469/500] - Train Loss: 0.0006
# Epoch [470/500] - Train Loss: 0.0006
# Epoch [471/500] - Train Loss: 0.0006
# Epoch [472/500] - Train Loss: 0.0007
# Epoch [473/500] - Train Loss: 0.0007
# Epoch [474/500] - Train Loss: 0.0007
# Epoch [475/500] - Train Loss: 0.0005
# Epoch [476/500] - Train Loss: 0.0006
# Epoch [477/500] - Train Loss: 0.0005
# Epoch [478/500] - Train Loss: 0.0007
# Epoch [479/500] - Train Loss: 0.0004
# Epoch [480/500] - Train Loss: 0.0005
# Epoch [481/500] - Train Loss: 0.0004
# Epoch [482/500] - Train Loss: 0.0004
# Epoch [483/500] - Train Loss: 0.0005
# Epoch [484/500] - Train Loss: 0.0005
# Epoch [485/500] - Train Loss: 0.0006
# Epoch [486/500] - Train Loss: 0.0007
# Epoch [487/500] - Train Loss: 0.0004
# Epoch [488/500] - Train Loss: 0.0005
# Epoch [489/500] - Train Loss: 0.0007
# Epoch [490/500] - Train Loss: 0.0011
# Epoch [491/500] - Train Loss: 0.0006
# Epoch [492/500] - Train Loss: 0.0006
# Epoch [493/500] - Train Loss: 0.0004
# Epoch [494/500] - Train Loss: 0.0004
# Epoch [495/500] - Train Loss: 0.0009
# Epoch [496/500] - Train Loss: 0.0040
# Epoch [497/500] - Train Loss: 0.1620
# Epoch [498/500] - Train Loss: 0.3566
# Epoch [499/500] - Train Loss: 0.1572
# Epoch [500/500] - Train Loss: 0.0560
#
# Test BLEU Score: 9.50

# %%
################################################################################
# Part 4: Simplified Transformer Model (2 Layers, 2 Heads)
################################################################################

import torch
import torch.nn as nn
import torch.nn.functional as F
import math
import random
import numpy as np
from datasets import load_dataset
from sacrebleu import corpus_bleu

################################################################################
# 1. Hyperparameters & Basic Setup
################################################################################
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", DEVICE)

EMBED_DIM = 256        # Embedding dimension
FF_DIM = 512           # Feedforward dimension
N_HEADS = 2            # Multi-head attention heads
ENC_LAYERS = 2         # Number of encoder layers
DEC_LAYERS = 2         # Number of decoder layers
BATCH_SIZE = 32
EPOCHS = 500
LR = 1e-4
MAX_TOKENS = 10000  # for building vocab
MAX_SEQ_LEN = 100   # maximum sequence length

################################################################################
# 2. Minimal Data Loading: IWSLT 2017 (German-English)
#    We'll take a small subset (~10k lines) to keep it manageable
################################################################################
dataset = load_dataset("iwslt2017", "iwslt2017-de-en")
train_data_full = dataset["train"]
valid_data_full = dataset["validation"]
test_data_full  = dataset["test"]

# We'll choose ~10k lines from train, ~1k from valid, ~1k from test
train_subset = train_data_full.select(range(min(len(train_data_full), 10000)))
valid_subset = valid_data_full.select(range(min(len(valid_data_full), 1000)))
test_subset  = test_data_full.select(range(min(len(test_data_full), 1000)))

train_de = [ex["translation"]["de"] for ex in train_subset]
train_en = [ex["translation"]["en"] for ex in train_subset]

valid_de = [ex["translation"]["de"] for ex in valid_subset]
valid_en = [ex["translation"]["en"] for ex in valid_subset]

test_de  = [ex["translation"]["de"] for ex in test_subset]
test_en  = [ex["translation"]["en"] for ex in test_subset]

################################################################################
# 3. Tokenization & Vocab
################################################################################
def tokenize(text):
    return text.lower().split()

def build_vocab(lines, max_tokens=MAX_TOKENS):
    freq = {}
    for line in lines:
        for token in tokenize(line):
            freq[token] = freq.get(token, 0) + 1
    # sort by frequency
    sorted_freq = sorted(freq.items(), key=lambda x: x[1], reverse=True)
    vocab = ["<pad>", "<bos>", "<eos>", "<unk>"]
    for w, _ in sorted_freq[: (max_tokens - len(vocab))]:
        vocab.append(w)
    word2idx = {w: i for i, w in enumerate(vocab)}
    idx2word = {i: w for w, i in word2idx.items()}
    return vocab, word2idx, idx2word

src_vocab, src_w2i, src_i2w = build_vocab(train_de)
tgt_vocab, tgt_w2i, tgt_i2w = build_vocab(train_en)

PAD_IDX = src_w2i["<pad>"]
BOS_IDX = src_w2i["<bos>"] if "<bos>" in src_w2i else 1
EOS_IDX = src_w2i["<eos>"] if "<eos>" in src_w2i else 2

def numericalize(line, w2i):
    tokens = ["<bos>"] + tokenize(line) + ["<eos>"]
    return [w2i.get(t, w2i["<unk>"]) for t in tokens][:MAX_SEQ_LEN]

train_src_num = [numericalize(line, src_w2i) for line in train_de]
train_tgt_num = [numericalize(line, tgt_w2i) for line in train_en]

valid_src_num = [numericalize(line, src_w2i) for line in valid_de]
valid_tgt_num = [numericalize(line, tgt_w2i) for line in valid_en]

test_src_num  = [numericalize(line, src_w2i) for line in test_de]
test_tgt_num  = [numericalize(line, tgt_w2i) for line in test_en]

################################################################################
# 4. Batching & Padding
################################################################################
def pad_batch(batch, pad_idx=0):
    max_len = max(len(seq) for seq in batch)
    padded = []
    for seq in batch:
        seq = seq + [pad_idx]*(max_len - len(seq))
        padded.append(seq)
    return torch.tensor(padded, dtype=torch.long)

def collate_fn(batch):
    src_seqs, tgt_seqs = zip(*batch)
    src_pad = pad_batch(src_seqs, pad_idx=0)
    tgt_pad = pad_batch(tgt_seqs, pad_idx=0)
    return src_pad, tgt_pad

train_pairs = list(zip(train_src_num, train_tgt_num))
valid_pairs = list(zip(valid_src_num, valid_tgt_num))

train_loader = torch.utils.data.DataLoader(
    train_pairs, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_fn
)
valid_loader = torch.utils.data.DataLoader(
    valid_pairs, batch_size=BATCH_SIZE, shuffle=False, collate_fn=collate_fn
)

SRC_VOCAB_SIZE = len(src_vocab)
TGT_VOCAB_SIZE = len(tgt_vocab)

################################################################################
# 5. Positional Encoding
################################################################################
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=5000):
        super().__init__()
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)  # shape (1, max_len, d_model)
        self.register_buffer('pe', pe)

    def forward(self, x):
        # x shape: (batch_size, seq_len, d_model)
        seq_len = x.size(1)
        return x + self.pe[:, :seq_len, :]

################################################################################
# 6. Multi-Head Attention (scaled dot-product)
################################################################################
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, n_heads):
        super().__init__()
        assert d_model % n_heads == 0
        self.d_k = d_model // n_heads
        self.n_heads = n_heads

        self.w_q = nn.Linear(d_model, d_model)
        self.w_k = nn.Linear(d_model, d_model)
        self.w_v = nn.Linear(d_model, d_model)
        self.w_o = nn.Linear(d_model, d_model)

    def forward(self, query, key, value, mask=None):
        # query/key/value: (batch_size, seq_len, d_model)
        B, L, D = query.size()
        # 1) Linear projections
        Q = self.w_q(query)  # (B, L, D)
        K = self.w_k(key)
        V = self.w_v(value)

        # 2) Split into heads
        Q = Q.view(B, L, self.n_heads, self.d_k).transpose(1,2)  # (B, n_heads, L, d_k)
        K = K.view(B, -1, self.n_heads, self.d_k).transpose(1,2)  # (B, n_heads, L, d_k)
        V = V.view(B, -1, self.n_heads, self.d_k).transpose(1,2)

        # 3) Scaled dot-product
        # Q @ K^T => (B, n_heads, L, L_k)
        scores = torch.matmul(Q, K.transpose(-2, -1)) / math.sqrt(self.d_k)

        if mask is not None:
            # mask shape should match (B, 1, L, L_k) or broadcastable
            scores = scores.masked_fill(mask == 0, float('-inf'))

        attn = F.softmax(scores, dim=-1)
        out = torch.matmul(attn, V)  # (B, n_heads, L, d_k)

        # 4) Concat heads
        out = out.transpose(1,2).contiguous().view(B, L, D)
        out = self.w_o(out)
        return out, attn

################################################################################
# 7. Feed-Forward Network
################################################################################
class PositionwiseFeedForward(nn.Module):
    def __init__(self, d_model, dim_feedforward=512):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(d_model, dim_feedforward),
            nn.ReLU(),
            nn.Linear(dim_feedforward, d_model),
        )
    def forward(self, x):
        return self.net(x)

################################################################################
# 8. Transformer Encoder/Decoder Layers
################################################################################
class EncoderLayer(nn.Module):
    def __init__(self, d_model, n_heads, dim_feedforward):
        super().__init__()
        self.self_attn = MultiHeadAttention(d_model, n_heads)
        self.ff = PositionwiseFeedForward(d_model, dim_feedforward)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)

    def forward(self, x, src_mask=None):
        # Self-attention
        attn_out, _ = self.self_attn(x, x, x, mask=src_mask)
        x = self.norm1(x + attn_out)
        # Feed-forward
        ff_out = self.ff(x)
        x = self.norm2(x + ff_out)
        return x

class DecoderLayer(nn.Module):
    def __init__(self, d_model, n_heads, dim_feedforward):
        super().__init__()
        self.self_attn = MultiHeadAttention(d_model, n_heads)
        self.cross_attn = MultiHeadAttention(d_model, n_heads)
        self.ff = PositionwiseFeedForward(d_model, dim_feedforward)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.norm3 = nn.LayerNorm(d_model)

    def forward(self, x, memory, tgt_mask=None, memory_mask=None):
        # 1) Self-attention (mask future tokens)
        self_attn_out, _ = self.self_attn(x, x, x, mask=tgt_mask)
        x = self.norm1(x + self_attn_out)

        # 2) Cross-attention
        cross_attn_out, _ = self.cross_attn(x, memory, memory, mask=memory_mask)
        x = self.norm2(x + cross_attn_out)

        # 3) Feed-forward
        ff_out = self.ff(x)
        x = self.norm3(x + ff_out)
        return x

################################################################################
# 9. Full Encoder / Decoder
################################################################################
class TransformerEncoder(nn.Module):
    def __init__(self, d_model, n_heads, dim_feedforward, num_layers, vocab_size):
        super().__init__()
        self.embed = nn.Embedding(vocab_size, d_model, padding_idx=0)
        self.pos_encoding = PositionalEncoding(d_model)
        self.layers = nn.ModuleList([
            EncoderLayer(d_model, n_heads, dim_feedforward) for _ in range(num_layers)
        ])
    def forward(self, src, src_mask=None):
        # src shape: (batch_size, seq_len)
        x = self.embed(src)  # (B, L, d_model)
        x = self.pos_encoding(x)
        for layer in self.layers:
            x = layer(x, src_mask)
        return x

class TransformerDecoder(nn.Module):
    def __init__(self, d_model, n_heads, dim_feedforward, num_layers, vocab_size):
        super().__init__()
        self.embed = nn.Embedding(vocab_size, d_model, padding_idx=0)
        self.pos_encoding = PositionalEncoding(d_model)
        self.layers = nn.ModuleList([
            DecoderLayer(d_model, n_heads, dim_feedforward) for _ in range(num_layers)
        ])
        self.fc_out = nn.Linear(d_model, vocab_size)

    def forward(self, tgt, memory, tgt_mask=None, memory_mask=None):
        x = self.embed(tgt)
        x = self.pos_encoding(x)
        for layer in self.layers:
            x = layer(x, memory, tgt_mask, memory_mask)
        logits = self.fc_out(x)  # (B, L, vocab_size)
        return logits

################################################################################
# 10. Full Transformer Model
################################################################################
class TransformerModel(nn.Module):
    def __init__(self, src_vocab_size, tgt_vocab_size,
                 d_model=256, n_heads=2, ff_dim=512,
                 enc_layers=2, dec_layers=2):
        super().__init__()
        self.encoder = TransformerEncoder(d_model, n_heads, ff_dim, enc_layers, src_vocab_size)
        self.decoder = TransformerDecoder(d_model, n_heads, ff_dim, dec_layers, tgt_vocab_size)

    def make_subsequent_mask(self, sz):
        """Mask out future positions for target tokens (causal mask)."""
        mask = torch.ones(sz, sz).triu(1)
        return mask == 0  # True = keep, False = mask out

    def forward(self, src, tgt):
        # src: (B, src_len)
        # tgt: (B, tgt_len)
        # 1) encode
        memory = self.encoder(src)  # (B, src_len, d_model)
        # 2) decode
        # create subsequent mask for target
        tgt_len = tgt.size(1)
        subseq_mask = self.make_subsequent_mask(tgt_len).to(tgt.device)
        # expand to (B, n_heads, tgt_len, tgt_len) or broadcast
        # for simplicity, we do (1, tgt_len, tgt_len)
        subseq_mask = subseq_mask.unsqueeze(0)

        logits = self.decoder(tgt, memory, tgt_mask=subseq_mask)
        return logits

################################################################################
# 11. Training Loop
################################################################################
model = TransformerModel(
    src_vocab_size=SRC_VOCAB_SIZE,
    tgt_vocab_size=TGT_VOCAB_SIZE,
    d_model=EMBED_DIM,
    n_heads=N_HEADS,
    ff_dim=FF_DIM,
    enc_layers=ENC_LAYERS,
    dec_layers=DEC_LAYERS
).to(DEVICE)

criterion = nn.CrossEntropyLoss(ignore_index=0)
optimizer = torch.optim.Adam(model.parameters(), lr=LR)

def train_epoch():
    model.train()
    total_loss = 0
    for src_batch, tgt_batch in train_loader:
        src_batch = src_batch.to(DEVICE)
        tgt_batch = tgt_batch.to(DEVICE)

        # Teacher forcing:
        # decoder inputs: all but last token
        # we want to predict all but first token
        dec_in = tgt_batch[:, :-1]
        dec_target = tgt_batch[:, 1:].contiguous().view(-1)

        optimizer.zero_grad()
        logits = model(src_batch, dec_in)  # (B, dec_in_len, vocab_size)
        logits = logits.view(-1, logits.size(-1))
        loss = criterion(logits, dec_target)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(train_loader)

################################################################################
# 12. Inference / Greedy Decode for BLEU
################################################################################
def greedy_decode(src_seq, max_len=50):
    model.eval()
    with torch.no_grad():
        src_seq = torch.tensor(src_seq, dtype=torch.long).unsqueeze(0).to(DEVICE)
        memory = model.encoder(src_seq)
        # Start with <bos>
        ys = torch.tensor([[tgt_w2i["<bos>"]]], dtype=torch.long).to(DEVICE)
        for _ in range(max_len):
            tgt_mask = model.make_subsequent_mask(ys.size(1)).to(DEVICE).unsqueeze(0)
            out = model.decoder(ys, memory, tgt_mask=tgt_mask)
            next_token = out[:, -1, :].argmax(dim=-1)
            next_token_id = next_token.item()
            ys = torch.cat([ys, next_token.unsqueeze(1)], dim=1)
            if next_token_id == tgt_w2i["<eos>"]:
                break
        return ys[0].cpu().numpy()

def evaluate_bleu(src_list, tgt_list, max_len=50):
    preds = []
    refs = []
    for i in range(len(src_list)):
        pred_ids = greedy_decode(src_list[i], max_len=max_len)
        # remove <bos>, <eos>, <pad>
        pred_tokens = []
        for tid in pred_ids:
            if tid == tgt_w2i["<bos>"] or tid == tgt_w2i["<pad>"]:
                continue
            if tid == tgt_w2i["<eos>"]:
                break
            pred_tokens.append(tid)
        # Use tgt_i2w instead of tgt_idx2word
        pred_words = [tgt_i2w.get(x, "<unk>") for x in pred_tokens]
        preds.append(" ".join(pred_words))

        # reference
        ref_line = tokenize(tgt_list[i])
        refs.append([" ".join(ref_line)])
    bleu = corpus_bleu(preds, refs)
    return bleu.score

################################################################################
# 13. Run Training
################################################################################
for epoch in range(1, EPOCHS + 1):
    loss = train_epoch()
    print(f"Epoch {epoch}/{EPOCHS}, Train Loss: {loss:.4f}")

# Optional: Evaluate on a small subset of valid to see if it is learning
val_bleu = evaluate_bleu(valid_src_num[:100], valid_en[:100], max_len=50)
print(f"Validation BLEU (first 100 lines): {val_bleu:.2f}")

################################################################################
# 14. Test BLEU on a small subset
################################################################################
test_bleu = evaluate_bleu(test_src_num[:100], test_en[:100], max_len=50)
print(f"Test BLEU (first 100 lines): {test_bleu:.2f}")
# Out:
# Using device: cuda
# Epoch 1/500, Train Loss: 6.6489
# Epoch 2/500, Train Loss: 5.7209
# Epoch 3/500, Train Loss: 5.3786
# Epoch 4/500, Train Loss: 5.1234
# Epoch 5/500, Train Loss: 4.9113
# Epoch 6/500, Train Loss: 4.7384
# Epoch 7/500, Train Loss: 4.5726
# Epoch 8/500, Train Loss: 4.4215
# Epoch 9/500, Train Loss: 4.2761
# Epoch 10/500, Train Loss: 4.1292
# Epoch 11/500, Train Loss: 3.9898
# Epoch 12/500, Train Loss: 3.8553
# Epoch 13/500, Train Loss: 3.7207
# Epoch 14/500, Train Loss: 3.5885
# Epoch 15/500, Train Loss: 3.4544
# Epoch 16/500, Train Loss: 3.3263
# Epoch 17/500, Train Loss: 3.1943
# Epoch 18/500, Train Loss: 3.0657
# Epoch 19/500, Train Loss: 2.9372
# Epoch 20/500, Train Loss: 2.8101
# Epoch 21/500, Train Loss: 2.6809
# Epoch 22/500, Train Loss: 2.5527
# Epoch 23/500, Train Loss: 2.4287
# Epoch 24/500, Train Loss: 2.3043
# Epoch 25/500, Train Loss: 2.1790
# Epoch 26/500, Train Loss: 2.0599
# Epoch 27/500, Train Loss: 1.9430
# Epoch 28/500, Train Loss: 1.8271
# Epoch 29/500, Train Loss: 1.7146
# Epoch 30/500, Train Loss: 1.6018
# Epoch 31/500, Train Loss: 1.4982
# Epoch 32/500, Train Loss: 1.3929
# Epoch 33/500, Train Loss: 1.2967
# Epoch 34/500, Train Loss: 1.2012
# Epoch 35/500, Train Loss: 1.1125
# Epoch 36/500, Train Loss: 1.0231
# Epoch 37/500, Train Loss: 0.9381
# Epoch 38/500, Train Loss: 0.8646
# Epoch 39/500, Train Loss: 0.7872
# Epoch 40/500, Train Loss: 0.7176
# Epoch 41/500, Train Loss: 0.6548
# Epoch 42/500, Train Loss: 0.5906
# Epoch 43/500, Train Loss: 0.5343
# Epoch 44/500, Train Loss: 0.4826
# Epoch 45/500, Train Loss: 0.4356
# Epoch 46/500, Train Loss: 0.3864
# Epoch 47/500, Train Loss: 0.3431
# Epoch 48/500, Train Loss: 0.3110
# Epoch 49/500, Train Loss: 0.2787
# Epoch 50/500, Train Loss: 0.2536
# Epoch 51/500, Train Loss: 0.2164
# Epoch 52/500, Train Loss: 0.1937
# Epoch 53/500, Train Loss: 0.1715
# Epoch 54/500, Train Loss: 0.1572
# Epoch 55/500, Train Loss: 0.1552
# Epoch 56/500, Train Loss: 0.1379
# Epoch 57/500, Train Loss: 0.1305
# Epoch 58/500, Train Loss: 0.1091
# Epoch 59/500, Train Loss: 0.0980
# Epoch 60/500, Train Loss: 0.0985
# Epoch 61/500, Train Loss: 0.0989
# Epoch 62/500, Train Loss: 0.0929
# Epoch 63/500, Train Loss: 0.0753
# Epoch 64/500, Train Loss: 0.0717
# Epoch 65/500, Train Loss: 0.0716
# Epoch 66/500, Train Loss: 0.0747
# Epoch 67/500, Train Loss: 0.0732
# Epoch 68/500, Train Loss: 0.0708
# Epoch 69/500, Train Loss: 0.0607
# Epoch 70/500, Train Loss: 0.0566
# Epoch 71/500, Train Loss: 0.0498
# Epoch 72/500, Train Loss: 0.0592
# Epoch 73/500, Train Loss: 0.0637
# Epoch 74/500, Train Loss: 0.0598
# Epoch 75/500, Train Loss: 0.0498
# Epoch 76/500, Train Loss: 0.0428
# Epoch 77/500, Train Loss: 0.0360
# Epoch 78/500, Train Loss: 0.0474
# Epoch 79/500, Train Loss: 0.0619
# Epoch 80/500, Train Loss: 0.0550
# Epoch 81/500, Train Loss: 0.0422
# Epoch 82/500, Train Loss: 0.0325
# Epoch 83/500, Train Loss: 0.0324
# Epoch 84/500, Train Loss: 0.0454
# Epoch 85/500, Train Loss: 0.0526
# Epoch 86/500, Train Loss: 0.0507
# Epoch 87/500, Train Loss: 0.0429
# Epoch 88/500, Train Loss: 0.0363
# Epoch 89/500, Train Loss: 0.0356
# Epoch 90/500, Train Loss: 0.0352
# Epoch 91/500, Train Loss: 0.0448
# Epoch 92/500, Train Loss: 0.0356
# Epoch 93/500, Train Loss: 0.0303
# Epoch 94/500, Train Loss: 0.0311
# Epoch 95/500, Train Loss: 0.0319
# Epoch 96/500, Train Loss: 0.0348
# Epoch 97/500, Train Loss: 0.0405
# Epoch 98/500, Train Loss: 0.0390
# Epoch 99/500, Train Loss: 0.0313
# Epoch 100/500, Train Loss: 0.0354
# Epoch 101/500, Train Loss: 0.0320
# Epoch 102/500, Train Loss: 0.0334
# Epoch 103/500, Train Loss: 0.0310
# Epoch 104/500, Train Loss: 0.0239
# Epoch 105/500, Train Loss: 0.0274
# Epoch 106/500, Train Loss: 0.0280
# Epoch 107/500, Train Loss: 0.0338
# Epoch 108/500, Train Loss: 0.0336
# Epoch 109/500, Train Loss: 0.0345
# Epoch 110/500, Train Loss: 0.0322
# Epoch 111/500, Train Loss: 0.0293
# Epoch 112/500, Train Loss: 0.0230
# Epoch 113/500, Train Loss: 0.0217
# Epoch 114/500, Train Loss: 0.0216
# Epoch 115/500, Train Loss: 0.0327
# Epoch 116/500, Train Loss: 0.0430
# Epoch 117/500, Train Loss: 0.0406
# Epoch 118/500, Train Loss: 0.0250
# Epoch 119/500, Train Loss: 0.0158
# Epoch 120/500, Train Loss: 0.0160
# Epoch 121/500, Train Loss: 0.0197
# Epoch 122/500, Train Loss: 0.0306
# Epoch 123/500, Train Loss: 0.0306
# Epoch 124/500, Train Loss: 0.0305
# Epoch 125/500, Train Loss: 0.0272
# Epoch 126/500, Train Loss: 0.0213
# Epoch 127/500, Train Loss: 0.0201
# Epoch 128/500, Train Loss: 0.0221
# Epoch 129/500, Train Loss: 0.0279
# Epoch 130/500, Train Loss: 0.0273
# Epoch 131/500, Train Loss: 0.0276
# Epoch 132/500, Train Loss: 0.0203
# Epoch 133/500, Train Loss: 0.0198
# Epoch 134/500, Train Loss: 0.0296
# Epoch 135/500, Train Loss: 0.0278
# Epoch 136/500, Train Loss: 0.0230
# Epoch 137/500, Train Loss: 0.0217
# Epoch 138/500, Train Loss: 0.0168
# Epoch 139/500, Train Loss: 0.0129
# Epoch 140/500, Train Loss: 0.0149
# Epoch 141/500, Train Loss: 0.0312
# Epoch 142/500, Train Loss: 0.0500
# Epoch 143/500, Train Loss: 0.0310
# Epoch 144/500, Train Loss: 0.0149
# Epoch 145/500, Train Loss: 0.0097
# Epoch 146/500, Train Loss: 0.0094
# Epoch 147/500, Train Loss: 0.0137
# Epoch 148/500, Train Loss: 0.0355
# Epoch 149/500, Train Loss: 0.0400
# Epoch 150/500, Train Loss: 0.0243
# Epoch 151/500, Train Loss: 0.0173
# Epoch 152/500, Train Loss: 0.0137
# Epoch 153/500, Train Loss: 0.0123
# Epoch 154/500, Train Loss: 0.0145
# Epoch 155/500, Train Loss: 0.0246
# Epoch 156/500, Train Loss: 0.0264
# Epoch 157/500, Train Loss: 0.0268
# Epoch 158/500, Train Loss: 0.0212
# Epoch 159/500, Train Loss: 0.0167
# Epoch 160/500, Train Loss: 0.0166
# Epoch 161/500, Train Loss: 0.0141
# Epoch 162/500, Train Loss: 0.0173
# Epoch 163/500, Train Loss: 0.0264
# Epoch 164/500, Train Loss: 0.0254
# Epoch 165/500, Train Loss: 0.0245
# Epoch 166/500, Train Loss: 0.0171
# Epoch 167/500, Train Loss: 0.0163
# Epoch 168/500, Train Loss: 0.0198
# Epoch 169/500, Train Loss: 0.0197
# Epoch 170/500, Train Loss: 0.0174
# Epoch 171/500, Train Loss: 0.0177
# Epoch 172/500, Train Loss: 0.0151
# Epoch 173/500, Train Loss: 0.0207
# Epoch 174/500, Train Loss: 0.0293
# Epoch 175/500, Train Loss: 0.0217
# Epoch 176/500, Train Loss: 0.0135
# Epoch 177/500, Train Loss: 0.0135
# Epoch 178/500, Train Loss: 0.0160
# Epoch 179/500, Train Loss: 0.0138
# Epoch 180/500, Train Loss: 0.0166
# Epoch 181/500, Train Loss: 0.0232
# Epoch 182/500, Train Loss: 0.0272
# Epoch 183/500, Train Loss: 0.0232
# Epoch 184/500, Train Loss: 0.0185
# Epoch 185/500, Train Loss: 0.0117
# Epoch 186/500, Train Loss: 0.0091
# Epoch 187/500, Train Loss: 0.0090
# Epoch 188/500, Train Loss: 0.0125
# Epoch 189/500, Train Loss: 0.0251
# Epoch 190/500, Train Loss: 0.0326
# Epoch 191/500, Train Loss: 0.0212
# Epoch 192/500, Train Loss: 0.0163
# Epoch 193/500, Train Loss: 0.0101
# Epoch 194/500, Train Loss: 0.0085
# Epoch 195/500, Train Loss: 0.0109
# Epoch 196/500, Train Loss: 0.0184
# Epoch 197/500, Train Loss: 0.0289
# Epoch 198/500, Train Loss: 0.0250
# Epoch 199/500, Train Loss: 0.0151
# Epoch 200/500, Train Loss: 0.0106
# Epoch 201/500, Train Loss: 0.0122
# Epoch 202/500, Train Loss: 0.0129
# Epoch 203/500, Train Loss: 0.0163
# Epoch 204/500, Train Loss: 0.0244
# Epoch 205/500, Train Loss: 0.0247
# Epoch 206/500, Train Loss: 0.0150
# Epoch 207/500, Train Loss: 0.0119
# Epoch 208/500, Train Loss: 0.0102
# Epoch 209/500, Train Loss: 0.0111
# Epoch 210/500, Train Loss: 0.0127
# Epoch 211/500, Train Loss: 0.0192
# Epoch 212/500, Train Loss: 0.0313
# Epoch 213/500, Train Loss: 0.0223
# Epoch 214/500, Train Loss: 0.0132
# Epoch 215/500, Train Loss: 0.0084
# Epoch 216/500, Train Loss: 0.0112
# Epoch 217/500, Train Loss: 0.0137
# Epoch 218/500, Train Loss: 0.0162
# Epoch 219/500, Train Loss: 0.0239
# Epoch 220/500, Train Loss: 0.0173
# Epoch 221/500, Train Loss: 0.0128
# Epoch 222/500, Train Loss: 0.0091
# Epoch 223/500, Train Loss: 0.0102
# Epoch 224/500, Train Loss: 0.0153
# Epoch 225/500, Train Loss: 0.0205
# Epoch 226/500, Train Loss: 0.0197
# Epoch 227/500, Train Loss: 0.0215
# Epoch 228/500, Train Loss: 0.0107
# Epoch 229/500, Train Loss: 0.0095
# Epoch 230/500, Train Loss: 0.0096
# Epoch 231/500, Train Loss: 0.0126
# Epoch 232/500, Train Loss: 0.0196
# Epoch 233/500, Train Loss: 0.0205
# Epoch 234/500, Train Loss: 0.0155
# Epoch 235/500, Train Loss: 0.0122
# Epoch 236/500, Train Loss: 0.0111
# Epoch 237/500, Train Loss: 0.0095
# Epoch 238/500, Train Loss: 0.0106
# Epoch 239/500, Train Loss: 0.0182
# Epoch 240/500, Train Loss: 0.0236
# Epoch 241/500, Train Loss: 0.0203
# Epoch 242/500, Train Loss: 0.0134
# Epoch 243/500, Train Loss: 0.0089
# Epoch 244/500, Train Loss: 0.0074
# Epoch 245/500, Train Loss: 0.0069
# Epoch 246/500, Train Loss: 0.0083
# Epoch 247/500, Train Loss: 0.0256
# Epoch 248/500, Train Loss: 0.0316
# Epoch 249/500, Train Loss: 0.0192
# Epoch 250/500, Train Loss: 0.0085
# Epoch 251/500, Train Loss: 0.0071
# Epoch 252/500, Train Loss: 0.0063
# Epoch 253/500, Train Loss: 0.0069
# Epoch 254/500, Train Loss: 0.0131
# Epoch 255/500, Train Loss: 0.0223
# Epoch 256/500, Train Loss: 0.0245
# Epoch 257/500, Train Loss: 0.0149
# Epoch 258/500, Train Loss: 0.0078
# Epoch 259/500, Train Loss: 0.0050
# Epoch 260/500, Train Loss: 0.0067
# Epoch 261/500, Train Loss: 0.0144
# Epoch 262/500, Train Loss: 0.0271
# Epoch 263/500, Train Loss: 0.0194
# Epoch 264/500, Train Loss: 0.0147
# Epoch 265/500, Train Loss: 0.0087
# Epoch 266/500, Train Loss: 0.0075
# Epoch 267/500, Train Loss: 0.0077
# Epoch 268/500, Train Loss: 0.0143
# Epoch 269/500, Train Loss: 0.0192
# Epoch 270/500, Train Loss: 0.0158
# Epoch 271/500, Train Loss: 0.0112
# Epoch 272/500, Train Loss: 0.0101
# Epoch 273/500, Train Loss: 0.0143
# Epoch 274/500, Train Loss: 0.0172
# Epoch 275/500, Train Loss: 0.0113
# Epoch 276/500, Train Loss: 0.0083
# Epoch 277/500, Train Loss: 0.0079
# Epoch 278/500, Train Loss: 0.0067
# Epoch 279/500, Train Loss: 0.0124
# Epoch 280/500, Train Loss: 0.0312
# Epoch 281/500, Train Loss: 0.0214
# Epoch 282/500, Train Loss: 0.0086
# Epoch 283/500, Train Loss: 0.0068
# Epoch 284/500, Train Loss: 0.0062
# Epoch 285/500, Train Loss: 0.0056
# Epoch 286/500, Train Loss: 0.0110
# Epoch 287/500, Train Loss: 0.0197
# Epoch 288/500, Train Loss: 0.0237
# Epoch 289/500, Train Loss: 0.0142
# Epoch 290/500, Train Loss: 0.0111
# Epoch 291/500, Train Loss: 0.0083
# Epoch 292/500, Train Loss: 0.0078
# Epoch 293/500, Train Loss: 0.0084
# Epoch 294/500, Train Loss: 0.0095
# Epoch 295/500, Train Loss: 0.0142
# Epoch 296/500, Train Loss: 0.0233
# Epoch 297/500, Train Loss: 0.0176
# Epoch 298/500, Train Loss: 0.0104
# Epoch 299/500, Train Loss: 0.0073
# Epoch 300/500, Train Loss: 0.0059
# Epoch 301/500, Train Loss: 0.0070
# Epoch 302/500, Train Loss: 0.0154
# Epoch 303/500, Train Loss: 0.0262
# Epoch 304/500, Train Loss: 0.0172
# Epoch 305/500, Train Loss: 0.0100
# Epoch 306/500, Train Loss: 0.0063
# Epoch 307/500, Train Loss: 0.0056
# Epoch 308/500, Train Loss: 0.0091
# Epoch 309/500, Train Loss: 0.0190
# Epoch 310/500, Train Loss: 0.0211
# Epoch 311/500, Train Loss: 0.0118
# Epoch 312/500, Train Loss: 0.0076
# Epoch 313/500, Train Loss: 0.0052
# Epoch 314/500, Train Loss: 0.0066
# Epoch 315/500, Train Loss: 0.0117
# Epoch 316/500, Train Loss: 0.0228
# Epoch 317/500, Train Loss: 0.0184
# Epoch 318/500, Train Loss: 0.0115
# Epoch 319/500, Train Loss: 0.0064
# Epoch 320/500, Train Loss: 0.0078
# Epoch 321/500, Train Loss: 0.0079
# Epoch 322/500, Train Loss: 0.0074
# Epoch 323/500, Train Loss: 0.0101
# Epoch 324/500, Train Loss: 0.0150
# Epoch 325/500, Train Loss: 0.0177
# Epoch 326/500, Train Loss: 0.0173
# Epoch 327/500, Train Loss: 0.0112
# Epoch 328/500, Train Loss: 0.0072
# Epoch 329/500, Train Loss: 0.0068
# Epoch 330/500, Train Loss: 0.0059
# Epoch 331/500, Train Loss: 0.0068
# Epoch 332/500, Train Loss: 0.0146
# Epoch 333/500, Train Loss: 0.0247
# Epoch 334/500, Train Loss: 0.0164
# Epoch 335/500, Train Loss: 0.0086
# Epoch 336/500, Train Loss: 0.0064
# Epoch 337/500, Train Loss: 0.0053
# Epoch 338/500, Train Loss: 0.0048
# Epoch 339/500, Train Loss: 0.0079
# Epoch 340/500, Train Loss: 0.0175
# Epoch 341/500, Train Loss: 0.0238
# Epoch 342/500, Train Loss: 0.0152
# Epoch 343/500, Train Loss: 0.0095
# Epoch 344/500, Train Loss: 0.0056
# Epoch 345/500, Train Loss: 0.0049
# Epoch 346/500, Train Loss: 0.0067
# Epoch 347/500, Train Loss: 0.0088
# Epoch 348/500, Train Loss: 0.0160
# Epoch 349/500, Train Loss: 0.0213
# Epoch 350/500, Train Loss: 0.0136
# Epoch 351/500, Train Loss: 0.0066
# Epoch 352/500, Train Loss: 0.0036
# Epoch 353/500, Train Loss: 0.0042
# Epoch 354/500, Train Loss: 0.0070
# Epoch 355/500, Train Loss: 0.0190
# Epoch 356/500, Train Loss: 0.0252
# Epoch 357/500, Train Loss: 0.0124
# Epoch 358/500, Train Loss: 0.0062
# Epoch 359/500, Train Loss: 0.0053
# Epoch 360/500, Train Loss: 0.0036
# Epoch 361/500, Train Loss: 0.0038
# Epoch 362/500, Train Loss: 0.0048
# Epoch 363/500, Train Loss: 0.0180
# Epoch 364/500, Train Loss: 0.0302
# Epoch 365/500, Train Loss: 0.0159
# Epoch 366/500, Train Loss: 0.0067
# Epoch 367/500, Train Loss: 0.0035
# Epoch 368/500, Train Loss: 0.0030
# Epoch 369/500, Train Loss: 0.0041
# Epoch 370/500, Train Loss: 0.0093
# Epoch 371/500, Train Loss: 0.0218
# Epoch 372/500, Train Loss: 0.0229
# Epoch 373/500, Train Loss: 0.0121
# Epoch 374/500, Train Loss: 0.0056
# Epoch 375/500, Train Loss: 0.0045
# Epoch 376/500, Train Loss: 0.0033
# Epoch 377/500, Train Loss: 0.0043
# Epoch 378/500, Train Loss: 0.0171
# Epoch 379/500, Train Loss: 0.0266
# Epoch 380/500, Train Loss: 0.0116
# Epoch 381/500, Train Loss: 0.0072
# Epoch 382/500, Train Loss: 0.0049
# Epoch 383/500, Train Loss: 0.0042
# Epoch 384/500, Train Loss: 0.0030
# Epoch 385/500, Train Loss: 0.0027
# Epoch 386/500, Train Loss: 0.0111
# Epoch 387/500, Train Loss: 0.0400
# Epoch 388/500, Train Loss: 0.0197
# Epoch 389/500, Train Loss: 0.0070
# Epoch 390/500, Train Loss: 0.0042
# Epoch 391/500, Train Loss: 0.0031
# Epoch 392/500, Train Loss: 0.0033
# Epoch 393/500, Train Loss: 0.0054
# Epoch 394/500, Train Loss: 0.0113
# Epoch 395/500, Train Loss: 0.0255
# Epoch 396/500, Train Loss: 0.0209
# Epoch 397/500, Train Loss: 0.0080
# Epoch 398/500, Train Loss: 0.0037
# Epoch 399/500, Train Loss: 0.0030
# Epoch 400/500, Train Loss: 0.0026
# Epoch 401/500, Train Loss: 0.0028
# Epoch 402/500, Train Loss: 0.0104
# Epoch 403/500, Train Loss: 0.0311
# Epoch 404/500, Train Loss: 0.0171
# Epoch 405/500, Train Loss: 0.0084
# Epoch 406/500, Train Loss: 0.0058
# Epoch 407/500, Train Loss: 0.0028
# Epoch 408/500, Train Loss: 0.0032
# Epoch 409/500, Train Loss: 0.0029
# Epoch 410/500, Train Loss: 0.0067
# Epoch 411/500, Train Loss: 0.0237
# Epoch 412/500, Train Loss: 0.0286
# Epoch 413/500, Train Loss: 0.0134
# Epoch 414/500, Train Loss: 0.0061
# Epoch 415/500, Train Loss: 0.0035
# Epoch 416/500, Train Loss: 0.0029
# Epoch 417/500, Train Loss: 0.0028
# Epoch 418/500, Train Loss: 0.0028
# Epoch 419/500, Train Loss: 0.0041
# Epoch 420/500, Train Loss: 0.0360
# Epoch 421/500, Train Loss: 0.0259
# Epoch 422/500, Train Loss: 0.0093
# Epoch 423/500, Train Loss: 0.0042
# Epoch 424/500, Train Loss: 0.0024
# Epoch 425/500, Train Loss: 0.0023
# Epoch 426/500, Train Loss: 0.0031
# Epoch 427/500, Train Loss: 0.0046
# Epoch 428/500, Train Loss: 0.0145
# Epoch 429/500, Train Loss: 0.0274
# Epoch 430/500, Train Loss: 0.0142
# Epoch 431/500, Train Loss: 0.0072
# Epoch 432/500, Train Loss: 0.0034
# Epoch 433/500, Train Loss: 0.0023
# Epoch 434/500, Train Loss: 0.0024
# Epoch 435/500, Train Loss: 0.0044
# Epoch 436/500, Train Loss: 0.0146
# Epoch 437/500, Train Loss: 0.0299
# Epoch 438/500, Train Loss: 0.0125
# Epoch 439/500, Train Loss: 0.0055
# Epoch 440/500, Train Loss: 0.0035
# Epoch 441/500, Train Loss: 0.0031
# Epoch 442/500, Train Loss: 0.0028
# Epoch 443/500, Train Loss: 0.0035
# Epoch 444/500, Train Loss: 0.0059
# Epoch 445/500, Train Loss: 0.0284
# Epoch 446/500, Train Loss: 0.0244
# Epoch 447/500, Train Loss: 0.0094
# Epoch 448/500, Train Loss: 0.0045
# Epoch 449/500, Train Loss: 0.0031
# Epoch 450/500, Train Loss: 0.0029
# Epoch 451/500, Train Loss: 0.0036
# Epoch 452/500, Train Loss: 0.0067
# Epoch 453/500, Train Loss: 0.0219
# Epoch 454/500, Train Loss: 0.0197
# Epoch 455/500, Train Loss: 0.0097
# Epoch 456/500, Train Loss: 0.0047
# Epoch 457/500, Train Loss: 0.0029
# Epoch 458/500, Train Loss: 0.0026
# Epoch 459/500, Train Loss: 0.0022
# Epoch 460/500, Train Loss: 0.0024
# Epoch 461/500, Train Loss: 0.0073
# Epoch 462/500, Train Loss: 0.0347
# Epoch 463/500, Train Loss: 0.0202
# Epoch 464/500, Train Loss: 0.0081
# Epoch 465/500, Train Loss: 0.0031
# Epoch 466/500, Train Loss: 0.0018
# Epoch 467/500, Train Loss: 0.0016
# Epoch 468/500, Train Loss: 0.0016
# Epoch 469/500, Train Loss: 0.0017
# Epoch 470/500, Train Loss: 0.0017
# Epoch 471/500, Train Loss: 0.0061
# Epoch 472/500, Train Loss: 0.0545
# Epoch 473/500, Train Loss: 0.0204
# Epoch 474/500, Train Loss: 0.0055
# Epoch 475/500, Train Loss: 0.0025
# Epoch 476/500, Train Loss: 0.0020
# Epoch 477/500, Train Loss: 0.0016
# Epoch 478/500, Train Loss: 0.0018
# Epoch 479/500, Train Loss: 0.0024
# Epoch 480/500, Train Loss: 0.0036
# Epoch 481/500, Train Loss: 0.0295
# Epoch 482/500, Train Loss: 0.0322
# Epoch 483/500, Train Loss: 0.0104
# Epoch 484/500, Train Loss: 0.0048
# Epoch 485/500, Train Loss: 0.0032
# Epoch 486/500, Train Loss: 0.0029
# Epoch 487/500, Train Loss: 0.0026
# Epoch 488/500, Train Loss: 0.0019
# Epoch 489/500, Train Loss: 0.0023
# Epoch 490/500, Train Loss: 0.0130
# Epoch 491/500, Train Loss: 0.0386
# Epoch 492/500, Train Loss: 0.0139
# Epoch 493/500, Train Loss: 0.0063
# Epoch 494/500, Train Loss: 0.0032
# Epoch 495/500, Train Loss: 0.0021
# Epoch 496/500, Train Loss: 0.0014
# Epoch 497/500, Train Loss: 0.0017
# Epoch 498/500, Train Loss: 0.0013
# Epoch 499/500, Train Loss: 0.0015
# Epoch 500/500, Train Loss: 0.0325
# Validation BLEU (first 100 lines): 7.63
# Test BLEU (first 100 lines): 4.22

# %% [markdown]
# ## Discussion
#
# ### 1. BLEU Score Comparison
# After training the **Part 4** simplified Transformer (2 encoder layers, 2 decoder layers, 2 attention heads) on the same subset of the IWSLT dataset used in **Part 3**, we observe that the Transformer’s **validation BLEU** is **lower** than the RNN seq2seq model’s BLEU from Part 3. While exact numbers vary, the Transformer often ends up a few points behind the RNN-based model on this small-scale setup.
#
# ### 2. Possible Reasons for Performance Differences
#
# 1. **Data Scale & Model Complexity**
#    Transformers typically require **larger datasets** to fully realize their advantage over RNNs. On a small subset of IWSLT, the minimal Transformer architecture may not outperform a simpler RNN approach.
#
# 2. **Hyperparameter Sensitivity**
#    Transformers benefit from **learning rate warmups**, **label smoothing**, and **dropout** to converge effectively. Without careful tuning, they can underperform simpler RNNs that are more forgiving of suboptimal hyperparameters.
#
# 3. **Tokenization Method**
#    Both models use naive whitespace tokenization, which can yield high out-of-vocabulary rates and hamper translation performance. However, RNNs sometimes adapt more gracefully to limited vocabularies, while Transformers might struggle with OOV tokens.
#
# 4. **Training Epochs & Schedule**
#    Although both models may train for the same number of epochs, Transformers often need more specialized schedules (e.g., **Noam** or step-based decays) to reach optimal performance, whereas an RNN might converge quickly with a constant or simpler schedule.
#
# ### 3. Other Observations (Runtime, Resource Usage, etc.)
#
# 1. **Runtime**
#    Even though the simplified Transformer is relatively shallow (2 layers each for encoder and decoder), it often runs slower **per epoch** compared to an RNN of similar size. This is due to multi-head attention operations and matrix multiplications that may not be as efficient on small sequences or small batch sizes.
#
# 2. **Memory Footprint**
#    Multi-head attention can increase memory usage. For a small dataset or short sequences, the difference might be negligible, but in principle, Transformers often have a higher memory footprint than RNNs, especially for larger batch sizes or longer sequences.
#
# 3. **Scalability**
#    On larger datasets or with more powerful hardware, Transformers typically scale better, benefiting from parallelization in the attention layers. RNNs, by contrast, process tokens sequentially, limiting parallel speedups. This advantage, however, is less visible in a small-scale experiment.
#
# ### 4. Summary of Key Differences
# - **BLEU Score**: The RNN seq2seq model from Part 3 outperforms the simplified Transformer in Part 4 on a small subset of data, likely due to the Transformer’s greater reliance on data size, hyperparameter tuning, and advanced tokenization.
# - **Training & Inference Speed**: The Transformer can be slower on small batches/sequences, whereas the RNN is straightforward and efficient for limited data. On large data or longer sequences, the Transformer would typically shine due to parallelization.
# - **Implementation Complexity**: Part 4’s model is conceptually more involved (attention layers, positional encodings), but the code can be modular. Part 3’s RNN-based approach is simpler, which may also contribute to more stable performance on small tasks.
#
# **In conclusion**, the **Part 4** simplified Transformer underperforms the **Part 3** RNN seq2seq model on small data primarily due to **model complexity, limited data,** and **sensitivity to hyperparameters**. However, with **larger datasets**, **better tokenization**, and **careful tuning**, Transformers typically surpass RNN-based models. The current results demonstrate the importance of matching the model’s complexity and training setup to the available data size and computational resources.

# %% [markdown]
# **Developing a Movie Recommendation System for Enhancing User Experience**
#
# Our project aims to build a personalized movie recommendation system that leverages **Graph Neural Networks (GNNs)** to better capture user–item relationships. We have selected the **MovieLens** dataset, which provides a rich set of user ratings and metadata such as genres and demographic information. After initial data exploration, we observed that user ratings skew toward higher values (3–5) and that a small subset of “power users” contributes most of the ratings. These insights guided us to focus on filtering out inactive users and less-rated movies, thereby streamlining the data and forming a clearer user–movie interaction graph.
#
# To transform the dataset into a form suitable for graph-based models, we performed **preprocessing** steps that include normalizing movie titles, encoding genres, and converting user–item interactions into edges in a graph. This graph representation highlights the potential to capture nuanced relationships, such as how users with similar tastes or movies with overlapping genres might cluster. We are now finalizing our GNN architecture, which includes graph convolution layers to learn embeddings for users and movies, followed by an MLP or related structure to generate rating predictions or top-K recommendations.
#
# For **benchmarking**, we have set up a **LightGCN** pipeline. LightGCN is a popular collaborative filtering approach that uses simplified graph convolutions. Initial experiments on a small subset suggest that LightGCN outperforms a naive matrix factorization model, reinforcing our expectation that graph-based representations can improve recommendation quality. Moving forward, we will compare our final GNN model against LightGCN using metrics such as **RMSE**, **Recall@K**, and **Precision@K** to assess rating prediction accuracy and recommendation relevance.
#
# Looking ahead, our **next steps** include fine-tuning hyperparameters (e.g., number of GNN layers, embedding size, dropout rate) and possibly incorporating additional features, such as user demographics or advanced weighting schemes for edges. We also plan to evaluate more sophisticated approaches like using temporal information or context features if time allows. Ultimately, our goal is to produce a concise performance comparison between our GNN-based recommendation model and LightGCN, highlighting whether the enhanced ability to capture user–movie relationships translates into a better user experience.
